# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
import pandas as pd

recipes = pd.read_csv('data/recipes_sample.csv', delimiter=',', index_col=['id'])
reviews = pd.read_csv('data/reviews_sample.csv', delimiter=',', index_col=[0])
recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %%
reviews
# Out:
#             user_id  recipe_id        date  rating  \
# 370476        21752      57993  2003-05-01       5
# 624300       431813     142201  2007-09-16       5
# 187037       400708     252013  2008-01-10       4
# 706134   2001852463     404716  2017-12-11       5
# 312179        95810     129396  2008-03-14       5
# ...             ...        ...         ...     ...
# 1013457     1270706     335534  2009-05-17       4
# 158736      2282344       8701  2012-06-03       0
# 1059834      689540     222001  2008-04-08       5
# 453285   2000242659     354979  2015-06-02       5
# 691207       463435     415599  2010-09-30       5
#
#                                                     review
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
num_rows_1 = recipes.shape[0]
num_rows_2 = reviews.shape[0]
num_col_1 = recipes.shape[1]
num_col_2 = reviews.shape[1]

print(f'Количество строк recipes: {num_rows_1}')
print(f'Количество строк reviews: {num_rows_2}')
print(f'Количество столбцов recipes: {num_col_1}')
print(f'Количество столбцов reviews: {num_col_2}')
print(f'Типы данных столбцов recipes:')
print(recipes.dtypes)
print(f'Типы данных столбцов reviews:')
print(reviews.dtypes)
# Out:
# Количество строк recipes: 30000
# Количество строк reviews: 126696
# Количество столбцов recipes: 7
# Количество столбцов reviews: 5
# Типы данных столбцов recipes:
# name               object
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
# Типы данных столбцов reviews:
# user_id       int64
# recipe_id     int64
# date         object
# rating        int64
# review       object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('В recipes имеют пропуски столбцы, в которых значения больше 0:')
print(recipes.isnull().sum())
print('В reviews имеют пропуски столбцы, в которых значения больше 0:')
print(reviews.isnull().sum())

is_null = recipes.isnull()
row_with_null = is_null.any(axis=1)
rows_with_null = recipes[row_with_null]
count_1 = rows_with_null.shape[0]
is_null_2 = reviews.isnull()
row_with_null_2 = is_null_2.any(axis=1)
rows_with_null_2 = reviews[row_with_null_2]
count_2 = rows_with_null_2.shape[0]
num_rows_1 = recipes.shape[0]
num_rows_2 = reviews.shape[0]
res_1 = count_1 / num_rows_1 * 100
res_2 = count_2 / num_rows_2 * 100
print(f'Доля строк, содержащих пропуски в recipes: {res_1}%')
print(f'Доля строк, содержащих пропуски в reviews: {res_2}%')
# Out:
# В recipes имеют пропуски столбцы, в которых значения больше 0:
# name                  0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
# В reviews имеют пропуски столбцы, в которых значения больше 0:
# user_id       0
# recipe_id     0
# date          0
# rating        0
# review       17
# dtype: int64
# Доля строк, содержащих пропуски в recipes: 56.846666666666664%
# Доля строк, содержащих пропуски в reviews: 0.013417945317926377%

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('recipes')
print('minutes: ', recipes['minutes'].mean())
print('n_steps: ', recipes['n_steps'].mean())
print('n_ingredients: ', recipes['n_ingredients'].mean(), '\n')
print('reviews')
print('rating: ', reviews['rating'].mean())
# Out:
# recipes
# minutes:  123.35813333333333
# n_steps:  9.805582137161085
# n_ingredients:  9.008285984848484
#
# reviews
# rating:  4.410802235271832

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
recipes['name'].sample(n=10).to_frame()
# Out:
#                                                      name
# id
# 90447   beef  and pasta with mushroom sauce and vegeta...
# 191561                        chicken something casserole
# 402569                          hot cranberry apple cider
# 381753                  orange crush  soda pop  ice cream
# 114998                choose your crust creamy cheesecake
# 216073       lemon chicken scaloppine like t g i  fridays
# 197461                             spinach and dhal curry
# 223720                 south beach cream of broccoli soup
# 384067                         authentic italian meatloaf
# 482840  spanish spaghetti w pimento stuffed olives   z...

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.reset_index(drop=True)
# Out:
#            user_id  recipe_id        date  rating  \
# 0            21752      57993  2003-05-01       5
# 1           431813     142201  2007-09-16       5
# 2           400708     252013  2008-01-10       4
# 3       2001852463     404716  2017-12-11       5
# 4            95810     129396  2008-03-14       5
# ...            ...        ...         ...     ...
# 126691     1270706     335534  2009-05-17       4
# 126692     2282344       8701  2012-06-03       0
# 126693      689540     222001  2008-04-08       5
# 126694  2000242659     354979  2015-06-02       5
# 126695      463435     415599  2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
recipes.loc[(recipes['minutes'] <= 20) & (recipes['n_ingredients'] <= 5)]
# Out:
#                                                      name  minutes  \
# id
# 302399                                quick biscuit bread       20
# 303944                      peas  fit for a king or queen       20
# 100837                  hawaiian sunrise           mimosa        5
# 286484         tasty dish s   banana pudding in 2 minutes        2
# 11361                                  1 minute meatballs       13
# ...                                                   ...      ...
# 304922  zip and steam red potatoes with butter and garlic       13
# 74250                           ziplock vanilla ice cream       10
# 256177                      zucchini and corn with cheese       15
# 320622               zucchini with jalapeno monterey jack       10
# 162411                          zucchini with serrano ham       15
#
#         contributor_id   submitted  n_steps  \
# id
# 302399          213909  2008-05-06     11.0
# 303944          213909  2008-05-16      NaN
# ...

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes.dtypes
# Out:
# name                      object
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
recipes.loc[recipes['submitted'] <= '2010-01-01']
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 316950                     zuni caf zucchini pickles     2895           62264
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
recipes['description_length'] = recipes['description'].str.len()
recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          george s at the cove  black bean soup       90           35193
# 67664             healthy for them  yogurt popsicles       10           91970
# 38798                   i can t believe it s spinach       30            1533
# 35173                           italian  gut busters       45           22724
# 84797       love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  zurie s holey rustic olive and cheddar bread       80          200862
# 386977          zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   zydeco soup       60          227978
# 298512        cookies by design   cookies on a stick       29          506822
#
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes['name'] = recipes['name'].str.capitalize()
recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          George s at the cove  black bean soup       90           35193
# 67664             Healthy for them  yogurt popsicles       10           91970
# 38798                   I can t believe it s spinach       30            1533
# 35173                           Italian  gut busters       45           22724
# 84797       Love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  Zurie s holey rustic olive and cheddar bread       80          200862
# 386977          Zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   Zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   Zydeco soup       60          227978
# 298512        Cookies by design   cookies on a stick       29          506822
#
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes['name_word_count'] = recipes['name'].str.split().str.len()
recipes
# Out:
#                                                 name  minutes  contributor_id  \
# id
# 44123          George s at the cove  black bean soup       90           35193
# 67664             Healthy for them  yogurt popsicles       10           91970
# 38798                   I can t believe it s spinach       30            1533
# 35173                           Italian  gut busters       45           22724
# 84797       Love is in the air  beef fondue   sauces       25            4470
# ...                                              ...      ...             ...
# 267661  Zurie s holey rustic olive and cheddar bread       80          200862
# 386977          Zwetschgenkuchen  bavarian plum cake      240          177443
# 103312   Zwiebelkuchen   southwest german onion cake       75          161745
# 486161                                   Zydeco soup       60          227978
# 298512        Cookies by design   cookies on a stick       29          506822
#
# ...

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
print('Кол-во рецептов каждого участника')
count = recipes['contributor_id'].value_counts().reset_index()
count.columns = ['contributor_id', 'amount']
count
# Out:
# Кол-во рецептов каждого участника
#       contributor_id  amount
# 0              89831     421
# 1              37449     346
# 2              37779     345
# 3               1533     186
# 4             169430     183
# ...              ...     ...
# 8399         1061628       1
# 8400         1076183       1
# 8401          429061       1
# 8402           64032       1
# 8403          186118       1
#
# [8404 rows x 2 columns]

# %%
print('Максимальное кол-во рецептов')
str = count[count['amount']==count['amount'].max()]
str
# Out:
# Максимальное кол-во рецептов
#    contributor_id  amount
# 0           89831     421

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
print('Средний рейтинг каждого рецепта')
average = reviews.groupby(['recipe_id']).agg({'rating': ['mean']}).reset_index()
average.columns = ['recipe_id', 'average_rating']
average
# Out:
# Средний рейтинг каждого рецепта
#        recipe_id  average_rating
# 0             48        1.000000
# 1             55        4.750000
# 2             66        4.944444
# 3             91        4.750000
# 4             94        5.000000
# ...          ...             ...
# 28095     536547        5.000000
# 28096     536610        0.000000
# 28097     536728        4.000000
# 28098     536729        4.750000
# 28099     536747        0.000000
#
# [28100 rows x 2 columns]

# %%
recipes.reset_index(inplace = True)
absent = recipes['id'].isin(reviews['recipe_id']).value_counts()
print(absent)
print('Отзывы отсутствуют для 1900 рецептов')
# Out:
# True     28100
# False     1900
# Name: id, dtype: int64
# Отзывы отсутствуют для 1900 рецептов

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
recipes.groupby(recipes['submitted'].dt.year)['name'].count().to_frame()
# Out:
#            name
# submitted
# 1999        275
# 2000        104
# 2001        589
# 2002       2644
# 2003       2334
# 2004       2153
# 2005       3130
# 2006       3473
# 2007       4429
# 2008       4029
# 2009       2963
# 2010       1538
# 2011        922
# 2012        659
# 2013        490
# 2014        139
# 2015         42
# 2016         24
# 2017         39
# 2018         24

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
recipes_1 = recipes[recipes['id'].isin(reviews['recipe_id']) == True] 
new = recipes_1.merge(reviews, left_on='id', right_on='recipe_id', how = 'inner')
new = new[['recipe_id','name','user_id','rating']]
new.rename(columns={'recipe_id':'id'})
# Out:
#             id                                    name  user_id  rating
# 0        44123   George s at the cove  black bean soup   743566       5
# 1        44123   George s at the cove  black bean soup    76503       5
# 2        44123   George s at the cove  black bean soup    34206       5
# 3        67664      Healthy for them  yogurt popsicles   494084       5
# 4        67664      Healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             Zydeco soup   305531       5
# 126692  486161                             Zydeco soup  1271506       5
# 126693  486161                             Zydeco soup   724631       5
# 126694  486161                             Zydeco soup   133174       5
# 126695  298512  Cookies by design   cookies on a stick   804234       1
#
# [126696 rows x 4 columns]

# %%
absent = recipes_1['id'].isin(new['recipe_id']).value_counts()
f = reviews['recipe_id'].isin([223349]).any()
bool = new['recipe_id'].isin([223349]).any()
g = recipes['id'].isin([223349]).any()
print('В recipes есть рецепт 223349: ', g)
print('В reviews он отсутсвует: ', f)
print('В new его тоже нет: ', bool)
# Out:
# В recipes есть рецепт 223349:  True
# В reviews он отсутсвует:  False
# В new его тоже нет:  False

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
review_sort = reviews.groupby('recipe_id').count()
new_2 = recipes.merge(review_sort, left_on='id', right_on='recipe_id')[['id', 'name', 'user_id', 'review']]
new_2 = new_2.rename(columns={'review': 'review_count'})
new_2
# Out:
#            id                                          name  user_id  \
# 0       44123         George s at the cove  black bean soup        3
# 1       67664            Healthy for them  yogurt popsicles        8
# 2       38798                  I can t believe it s spinach        3
# 3       35173                          Italian  gut busters        1
# 4       84797      Love is in the air  beef fondue   sauces        8
# ...       ...                                           ...      ...
# 28095  267661  Zurie s holey rustic olive and cheddar bread        4
# 28096  386977          Zwetschgenkuchen  bavarian plum cake        2
# 28097  103312   Zwiebelkuchen   southwest german onion cake        6
# 28098  486161                                   Zydeco soup        6
# 28099  298512        Cookies by design   cookies on a stick        1
#
#        review_count
# 0                 3
# 1                 8
# 2                 3
# 3                 1
# 4                 8
# ...

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
new_2 = recipes.merge(reviews, left_on='id', right_on='recipe_id', how = 'left')
sort = new_2.groupby(new_2['submitted'].dt.year)['rating'].mean().to_frame().reset_index().sort_values(by='rating')
sort['submitted'].iloc[0]
# Out:
# 2017

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
sort_values = recipes.sort_values(by='name_word_count', ascending=False)
sort_values.to_csv('recipes_1.csv', sep=',')

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter("new_list.xlsx") as writer:
    new.to_excel(writer, sheet_name='Рецепты с оценками', index=False)
    new_2.to_excel(writer, sheet_name='Количество отзывов по рецептам', index=False)
    writer.save()
# Out:
# C:\Users\silak\AppData\Local\Temp\ipykernel_19216\2639551016.py:4: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
# C:\Users\silak\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")
